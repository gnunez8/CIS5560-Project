# %%
from pyspark.sql.types import *
from pyspark.sql.functions import *

from pyspark.ml import *
from pyspark.ml.regression import LinearRegression , DecisionTreeRegressor, RandomForestRegressor, GBTRegressionModel, GBTRegressor

from pyspark.ml.feature import VectorAssembler
from pyspark.ml.tuning import ParamGridBuilder, TrainValidationSplit, CrossValidator
from pyspark.ml.evaluation import RegressionEvaluator

from pyspark.ml.feature import VectorIndexer
from pyspark.ml.feature import VectorAssembler, MinMaxScaler
from pyspark.ml.linalg import Vectors

from pyspark.ml.evaluation import BinaryClassificationEvaluator

from pyspark.sql import SparkSession
from pyspark.sql import functions as F

from pyspark.context import SparkContext
from pyspark.mllib.evaluation import MulticlassMetrics
from pyspark.sql.session import SparkSession

# %%
#PYSPARK_CLI = True
#if PYSPARK_CLI:
	#sc = SparkContext.getOrCreate()
	#spark = SparkSession(sc)

# %%
# File location and type
#file_location = "/FileStore/tables/2016_UniversityOfCalifornia.csv"
path = ['/FileStore/tables/Project/*.csv']
file_type = "csv"

# CSV options
infer_schema = "true"
first_row_is_header = "true"
delimiter = ","

# The applied options are for CSV files. For other file types, these will be ignored.
df = spark.read.format(file_type).option("inferSchema", infer_schema)\
  .option("header", first_row_is_header) \
  .option("sep", delimiter) \
  .load(path)


df.show()

# %%
print("Whole Data Set")
display(df)

# %%
df.printSchema()

# Create a view or table

temp_table_name = "masterTable"

df.createOrReplaceTempView(temp_table_name)

dftemp=df.select('Year','EmployerName','Position','TotalWages', 'RegularPay', 'MaxPositionSalary', 'MinPositionSalary')
#dftemp.show()

# Commented out IPython magic to ensure Python compatibility.
# %sql
#select * from masterTable`

#df.take(10)

#df_sql = spark.sql("select * from masterTable LIMIT 10")
#display(df_sql)

#df.printSchema()

df2 = df.drop("DepartmentOrSubdivision", "ElectedOfficial", "Judicial","OtherPositions", "DefinedBenefitPlanContribution","EmployeesRetirementCostCovered", "DeferredCompensationPlan","HealthDentalVision", "TotalRetirementAndHealthContribution","PensionFormula", "EmployerURL","EmployerPopulation","IncludesUnfundedLiability", "SpecialDistrictActivities"," IncludesUnfundedLiability","SpecialDistrictType")
#df2.printSchema()

print("Dataset with Dropped Columns")
#df2.show()
# Out:
# root
#  |-- Year: integer (nullable = true)
#  |-- EmployerType: string (nullable = true)
#  |-- EmployerName: string (nullable = true)
#  |-- DepartmentOrSubdivision: string (nullable = true)
#  |-- Position: string (nullable = true)
#  |-- ElectedOfficial: boolean (nullable = true)
#  |-- Judicial: boolean (nullable = true)
#  |-- OtherPositions: string (nullable = true)
#  |-- MinPositionSalary: double (nullable = true)
#  |-- MaxPositionSalary: double (nullable = true)
#  |-- ReportedBaseWage: string (nullable = true)
#  |-- RegularPay: double (nullable = true)
#  |-- OvertimePay: double (nullable = true)
#  |-- LumpSumPay: double (nullable = true)
#  |-- OtherPay: double (nullable = true)
#  |-- TotalWages: double (nullable = true)
#  |-- DefinedBenefitPlanContribution: double (nullable = true)
#  |-- EmployeesRetirementCostCovered: double (nullable = true)
#  |-- DeferredCompensationPlan: double (nullable = true)
#  |-- HealthDentalVision: double (nullable = true)
#  |-- TotalRetirementAndHealthContribution: double (nullable = true)
#  |-- PensionFormula: string (nullable = true)
#  |-- EmployerURL: string (nullable = true)
#  |-- EmployerPopulation: integer (nullable = true)
#  |-- LastUpdatedDate: string (nullable = true)
#  |-- EmployerCounty: string (nullable = true)
#  |-- SpecialDistrictActivities: string (nullable = true)
#  |-- IncludesUnfundedLiability: boolean (nullable = true)
#  |-- SpecialDistrictType: string (nullable = true)
#
# Dataset with Dropped Columns

# %%
df3 = df2.na.fill(value=0).na.fill("NA")
print("Dataset with Dropped Columns")
df3.show()
# Out:
# Dataset with Dropped Columns
# +----+--------------+------------+--------------------+-----------------+-----------------+----------------+----------+-----------+----------+--------+----------+---------------+--------------+
# |Year|  EmployerType|EmployerName|            Position|MinPositionSalary|MaxPositionSalary|ReportedBaseWage|RegularPay|OvertimePay|LumpSumPay|OtherPay|TotalWages|LastUpdatedDate|EmployerCounty|
# +----+--------------+------------+--------------------+-----------------+-----------------+----------------+----------+-----------+----------+--------+----------+---------------+--------------+
# |2015|K-12 Education| ABC Unified|Assistant Supt-Ac...|         174489.0|         174489.0|              NA|  164375.0|        0.0|       0.0| 25677.0|  190052.0|     09/06/2017|   Los Angeles|
# |2015|K-12 Education| ABC Unified|Child Care Specia...|              0.0|              0.0|              NA|    2313.0|        0.0|       0.0|     0.0|    2313.0|     09/06/2017|   Los Angeles|
# |2015|K-12 Education| ABC Unified|Child Care Specia...|              0.0|              0.0|              NA|    6404.0|        0.0|       0.0|     0.0|    6404.0|     09/06/2017|   Los Angeles|
# |2015|K-12 Education| ABC Unified|   Child Ctr Teacher|              0.0|              0.0|              NA|    2623.0|        0.0|       0.0|     0.0|    2623.0|     09/06/2017|   Los Angeles|
# |2015|K-12 Education| ABC Unified|    Computer Tech-Lt|              0.0|              0.0|              NA|   22580.0|        0.0|       0.0|   272.0|   22852.0|     09/06/2017|   Los Angeles|
# |2015|K-12 Education| ABC Unified|    Computer Tech-Lt|              0.0|              0.0|              NA|   33115.0|        0.0|       0.0|  4264.0|   37379.0|     09/06/2017|   Los Angeles|
# |2015|K-12 Education| ABC Unified|Counseling Assistant|              0.0|              0.0|              NA|    4650.0|        0.0|       0.0|     0.0|    4650.0|     09/06/2017|   Los Angeles|
# |2015|K-12 Education| ABC Unified|    Director-Schools|         130548.0|         148680.0|              NA|  143216.0|        0.0|       0.0| 10853.0|  154069.0|     09/06/2017|   Los Angeles|
# |2015|K-12 Education| ABC Unified|  Division Assistant|          65652.0|          74796.0|              NA|   68672.0|      448.0|       0.0| 11329.0|   80449.0|     09/06/2017|   Los Angeles|
# |2015|K-12 Education| ABC Unified| Grant Support Staff|              0.0|              0.0|              NA|   10404.0|        0.0|       0.0|     0.0|   10404.0|     09/06/2017|   Los Angeles|
# |2015|K-12 Education| ABC Unified|Health & Safety Aide|              0.0|              0.0|              NA|     255.0|        0.0|       0.0|     0.0|     255.0|     09/06/2017|   Los Angeles|
# |2015|K-12 Education| ABC Unified|Health Outreach W...|              0.0|              0.0|              NA|    5880.0|        0.0|       0.0|     0.0|    5880.0|     09/06/2017|   Los Angeles|
# |2015|K-12 Education| ABC Unified|      Parent Liaison|              0.0|              0.0|              NA|   19580.0|        0.0|       0.0|     0.0|   19580.0|     09/06/2017|   Los Angeles|
# |2015|K-12 Education| ABC Unified|Principal-Elementary|              0.0|              0.0|              NA|   16736.0|        0.0|       0.0|     0.0|   16736.0|     09/06/2017|   Los Angeles|
# |2015|K-12 Education| ABC Unified|Research, Plannin...|          49760.0|          60529.0|              NA|   52326.0|        0.0|       0.0|  1207.0|   53533.0|     09/06/2017|   Los Angeles|
# |2015|K-12 Education| ABC Unified|        Secretary II|          33706.0|          41037.0|              NA|   37934.0|        0.0|       0.0|   641.0|   38575.0|     09/06/2017|   Los Angeles|
# |2015|K-12 Education| ABC Unified|        Secretary II|          40447.0|          49244.0|              NA|   46811.0|      107.0|       0.0|  2239.0|   49157.0|     09/06/2017|   Los Angeles|
# |2015|K-12 Education| ABC Unified|       Secretary III|          42481.0|          51700.0|              NA|   48422.0|        0.0|       0.0|  2308.0|   50730.0|     09/06/2017|   Los Angeles|
# |2015|K-12 Education| ABC Unified|Sr. Inst. Media Tech|          45140.0|          54884.0|              NA|   53242.0|     2617.0|       0.0|  2423.0|   58282.0|     09/06/2017|   Los Angeles|
# |2015|K-12 Education| ABC Unified|      Student Helper|              0.0|              0.0|              NA|    1287.0|        0.0|       0.0|     0.0|    1287.0|     09/06/2017|   Los Angeles|
# +----+--------------+------------+--------------------+-----------------+-----------------+----------------+----------+-----------+----------+--------+----------+---------------+--------------+
# only showing top 20 rows

# %%
splits = df3.randomSplit([0.7,0.3])
train = splits[0]
test = splits[1]
train_rows = train.count()
test_rows = test.count()
print("Training Rows:", train_rows, "Testing Rows:", test_rows)
# Out:
# Training Rows: 6553298 Testing Rows: 2806965

# %%
assembler = VectorAssembler(inputCols = ["RegularPay", "TotalWages","MaxPositionSalary", "MinPositionSalary"], outputCol="wages")

# %%
training = assembler.transform(train)
print("Displaying results from Training the dataset")
training.show()
# Out:
# Displaying results from Training the dataset
# +----+--------------+------------+--------------------+-----------------+-----------------+----------------+----------+-----------+----------+--------+----------+---------------+--------------+--------------------+
# |Year|  EmployerType|EmployerName|            Position|MinPositionSalary|MaxPositionSalary|ReportedBaseWage|RegularPay|OvertimePay|LumpSumPay|OtherPay|TotalWages|LastUpdatedDate|EmployerCounty|               wages|
# +----+--------------+------------+--------------------+-----------------+-----------------+----------------+----------+-----------+----------+--------+----------+---------------+--------------+--------------------+
# |2015|K-12 Education| ABC Unified|Abc Sec School In...|              0.0|              0.0|              NA|     276.0|        0.0|       0.0|     0.0|     276.0|     09/06/2017|   Los Angeles|[276.0,276.0,0.0,...|
# |2015|K-12 Education| ABC Unified|Abc Sec School In...|              0.0|              0.0|              NA|   16291.0|        0.0|       0.0|     0.0|   16291.0|     09/06/2017|   Los Angeles|[16291.0,16291.0,...|
# |2015|K-12 Education| ABC Unified|Abc Sec School In...|              0.0|              0.0|              NA|   19445.0|        0.0|       0.0|     0.0|   19445.0|     09/06/2017|   Los Angeles|[19445.0,19445.0,...|
# |2015|K-12 Education| ABC Unified|Abc Sec School In...|              0.0|              0.0|              NA|   25363.0|        0.0|       0.0|     0.0|   25363.0|     09/06/2017|   Los Angeles|[25363.0,25363.0,...|
# |2015|K-12 Education| ABC Unified|     Accounting Tech|              0.0|              0.0|              NA|    8282.0|      372.0|       0.0|     0.0|    8654.0|     09/06/2017|   Los Angeles|[8282.0,8654.0,0....|
# |2015|K-12 Education| ABC Unified|     Accounting Tech|          48053.0|          58426.0|              NA|       0.0|        0.0|       0.0|   164.0|     164.0|     09/06/2017|   Los Angeles|[0.0,164.0,58426....|
# |2015|K-12 Education| ABC Unified|     Accounting Tech|          48053.0|          58426.0|              NA|       0.0|        0.0|       0.0|   450.0|     450.0|     09/06/2017|   Los Angeles|[0.0,450.0,58426....|
# |2015|K-12 Education| ABC Unified|     Accounting Tech|          48053.0|          58426.0|              NA|   43955.0|      947.0|       0.0|  2096.0|   46998.0|     09/06/2017|   Los Angeles|[43955.0,46998.0,...|
# |2015|K-12 Education| ABC Unified|     Accounting Tech|          48053.0|          58426.0|              NA|   47347.0|      295.0|       0.0|  1530.0|   49172.0|     09/06/2017|   Los Angeles|[47347.0,49172.0,...|
# |2015|K-12 Education| ABC Unified|     Accounting Tech|          48053.0|          58426.0|              NA|   56294.0|      949.0|       0.0|  4620.0|   61863.0|     09/06/2017|   Los Angeles|[56294.0,61863.0,...|
# |2015|K-12 Education| ABC Unified|     Accounting Tech|          48053.0|          58426.0|              NA|   56294.0|     3582.0|       0.0|  4416.0|   64292.0|     09/06/2017|   Los Angeles|[56294.0,64292.0,...|
# |2015|K-12 Education| ABC Unified|Administrative As...|          65652.0|          74796.0|              NA|   57376.0|     1123.0|       0.0|  4710.0|   63209.0|     09/06/2017|   Los Angeles|[57376.0,63209.0,...|
# |2015|K-12 Education| ABC Unified|Administrative Se...|          59712.0|          67980.0|              NA|    3317.0|       92.0|       0.0|  9315.0|   12724.0|     09/06/2017|   Los Angeles|[3317.0,12724.0,6...|
# |2015|K-12 Education| ABC Unified|Administrative Se...|          59712.0|          67980.0|              NA|   57814.0|        0.0|       0.0|  3050.0|   60864.0|     09/06/2017|   Los Angeles|[57814.0,60864.0,...|
# |2015|K-12 Education| ABC Unified|Adult Ed Instruction|              0.0|              0.0|              NA|     360.0|        0.0|       0.0|     0.0|     360.0|     09/06/2017|   Los Angeles|[360.0,360.0,0.0,...|
# |2015|K-12 Education| ABC Unified|Adult School Stat...|          60000.0|          66047.0|              NA|   24281.0|        0.0|     246.0|   203.0|   24730.0|     09/06/2017|   Los Angeles|[24281.0,24730.0,...|
# |2015|K-12 Education| ABC Unified|Adult School Stat...|          60000.0|          66047.0|              NA|   34356.0|        0.0|     339.0|  1218.0|   35913.0|     09/06/2017|   Los Angeles|[34356.0,35913.0,...|
# |2015|K-12 Education| ABC Unified|Adult School Stat...|          60000.0|          66047.0|              NA|   36174.0|        0.0|     334.0|   244.0|   36752.0|     09/06/2017|   Los Angeles|[36174.0,36752.0,...|
# |2015|K-12 Education| ABC Unified|Adult School Stat...|          60000.0|          66047.0|              NA|   40964.0|        0.0|     278.0|   257.0|   41499.0|     09/06/2017|   Los Angeles|[40964.0,41499.0,...|
# |2015|K-12 Education| ABC Unified|Adult School Stat...|          60000.0|          66047.0|              NA|   41559.0|        0.0|       0.0|   460.0|   42019.0|     09/06/2017|   Los Angeles|[41559.0,42019.0,...|
# +----+--------------+------------+--------------------+-----------------+-----------------+----------------+----------+-----------+----------+--------+----------+---------------+--------------+--------------------+
# only showing top 20 rows

# %%
rf = RandomForestRegressor(labelCol="TotalWages", featuresCol="wages", numTrees=10, maxDepth=5)

# %%
pipeline = Pipeline(stages=[assembler, rf])
print("Displaying results from Staging the Assembler and RF")
model = pipeline.fit(train)
# Out:
# Displaying results from Staging the Assembler and RF

# %%
rfModel = model.stages[-1]
print(rfModel.toDebugString)

#importance column name can be changed

# import pandas as pd
#featureImp = pd.DataFrame(list(zip(assembler.getInputCols(),
#rfModel.featureImportances)),
#columns=["trueWages", "importance"])
#featureImp.sort_values(by="importance", ascending=False)

# %%
rf = RandomForestRegressor(labelCol="TotalWages",featuresCol="wages", numTrees=10, maxDepth=5)
# Combine stages into pipeline
pipeline = Pipeline(stages=[assembler, rf])
model = pipeline.fit(train)

# %%
prediction = model.transform(test)
predicted = prediction.select("wages", "prediction", "TotalWages")
print("Displaying results from the Prediction")
predicted.show()

#display(predicted)
# Out:
# Displaying results from the Prediction
# +--------------------+------------------+----------+
# |               wages|        prediction|TotalWages|
# +--------------------+------------------+----------+
# |[31897.0,34289.0,...| 32230.43158413585|   34289.0|
# |[47347.0,50478.0,...|  51539.4633605598|   50478.0|
# |[55969.0,61586.0,...| 60055.20260306975|   61586.0|
# |[56294.0,60744.0,...| 60055.20260306975|   60744.0|
# |[540.0,540.0,0.0,...| 1943.944408420543|     540.0|
# |[38979.0,39626.0,...| 42301.02740924526|   39626.0|
# |[44389.0,44840.0,...|46544.566807735435|   44840.0|
# |[45575.0,46305.0,...| 49426.14765858212|   46305.0|
# |[46973.0,47931.0,...| 49864.32043488817|   47931.0|
# |[49471.0,50219.0,...|51942.136885027096|   50219.0|
# |[59020.0,59992.0,...| 65917.31575096237|   59992.0|
# |[64563.0,65827.0,...|  70290.5658378546|   65827.0|
# |[64803.0,65871.0,...|  70290.5658378546|   65871.0|
# |[65833.0,66916.0,...|  70290.5658378546|   66916.0|
# |[66031.0,67609.0,...|  70290.5658378546|   67609.0|
# |[2957.0,2961.0,0....|2624.4109382392344|    2961.0|
# |[2980.0,2980.0,0....|2624.4109382392344|    2980.0|
# |[4325.0,4325.0,0....|2624.4109382392344|    4325.0|
# |[5574.0,5666.0,0....| 6169.866915664215|    5666.0|
# |[8226.0,8317.0,0....| 7206.169960416037|    8317.0|
# +--------------------+------------------+----------+
# only showing top 20 rows

# %%
#from pyspark.ml.evaluation import RegressionEvaluator
rf_evaluator = RegressionEvaluator(predictionCol="prediction", \
                                   labelCol="TotalWages",metricName="r2")
print("R Squared (R2) on test data = %g" % rf_evaluator.evaluate(prediction))
rf_evaluator = RegressionEvaluator(labelCol="TotalWages", predictionCol="prediction", metricName="rmse")
print("RMSE: %f" % rf_evaluator.evaluate(prediction))

#Starting GBT
# Out:
# R Squared (R2) on test data = 0.889008
# RMSE: 17253.777949

# %%
df3 = df2.na.fill(value=0).na.fill("NA")
#df3.show()

# %%
splits = df3.randomSplit([0.7,0.3])
train = splits[0]
test = splits[1]
train_rows = train.count()
test_rows = test.count()
print("Training Rows:", train_rows, "Testing Rows:", test_rows)
# Out:
# Training Rows: 6550260 Testing Rows: 2810003

# %%
assembler = VectorAssembler(inputCols = ["RegularPay", "TotalWages","MaxPositionSalary", "MinPositionSalary"], outputCol="wages")

# %%
training = assembler.transform(train)
#training.show()

# %%
gbt = GBTRegressor(labelCol="TotalWages", featuresCol="wages", maxDepth=5)

# %%
paramGrid = ParamGridBuilder()\
.addGrid(gbt.maxDepth, [2, 5])\
.addGrid(gbt.maxIter, [10, 20])\
.build()

# %%
#gbt_evaluator = RegressionEvaluator(predictionCol="prediction", \ labelCol="TotalWages",metricName="r2")

gbt_evaluator = RegressionEvaluator(predictionCol="prediction", labelCol="TotalWages", metricName="r2")

# %%
pipeline = Pipeline(stages=[assembler, gbt])

# %%
cv = CrossValidator(estimator=pipeline, evaluator= gbt_evaluator, estimatorParamMaps=paramGrid)

# %%
print("Displaying results from CrossValidation with the trained dataset")
model = cv.fit(train)
# Out:
# Displaying results from CrossValidation with the trained dataset

# %%
prediction = model.transform(test)
predicted = prediction.select("wages", "prediction", "TotalWages")
print("Displaying results from TrainValidationSplit with the Predicted dataset")
predicted.show()
# Out:
# Displaying results from TrainValidationSplit with the Predicted dataset
# +--------------------+------------------+----------+
# |               wages|        prediction|TotalWages|
# +--------------------+------------------+----------+
# |[31897.0,34289.0,...|  34572.5588365633|   34289.0|
# |[43955.0,46998.0,...| 48045.62950520257|   46998.0|
# |[47347.0,49172.0,...| 48045.62950520257|   49172.0|
# |[47347.0,50478.0,...|52462.623924493986|   50478.0|
# |[55969.0,61586.0,...|61653.309718778386|   61586.0|
# |[56294.0,61863.0,...|61653.309718778386|   61863.0|
# |[3317.0,12724.0,6...|12939.672514724653|   12724.0|
# |[38979.0,39626.0,...| 39336.42602898334|   39626.0|
# |[44389.0,44840.0,...| 43703.13219409577|   44840.0|
# |[45575.0,46305.0,...| 48051.07997088548|   46305.0|
# |[49471.0,50219.0,...|  52468.0743901769|   50219.0|
# |[55745.0,56705.0,...| 56893.88048049886|   56705.0|
# |[66723.0,67795.0,...| 67897.45906108731|   67795.0|
# |[1059.0,1059.0,0....| 915.6912916537415|    1059.0|
# |[3233.0,3270.0,0....| 3124.001087956406|    3270.0|
# |[4325.0,4325.0,0....| 4020.144882256075|    4325.0|
# |[5039.0,5131.0,0....| 5973.953562997987|    5131.0|
# |[5495.0,5495.0,0....| 5973.953562997987|    5495.0|
# |[9725.0,9918.0,0....| 10149.99978341936|    9918.0|
# |[9763.0,9909.0,0....| 10149.99978341936|    9909.0|
# +--------------------+------------------+----------+
# only showing top 20 rows

# %%
print("R Squared (R2) on test data = %g" % gbt_evaluator.evaluate(prediction))
gbt_evaluator = RegressionEvaluator(labelCol="TotalWages", predictionCol="prediction", metricName="rmse")
print("RMSE: %f" % gbt_evaluator.evaluate(prediction))
# Out:
# R Squared (R2) on test data = 0.899337
# RMSE: 16437.748252

# %%
cva = TrainValidationSplit(estimator= pipeline, evaluator=gbt_evaluator, estimatorParamMaps=paramGrid, trainRatio=0.8)


example = cva.fit(train)


# Transform the test data and generate predictions by applying the trained model
prediction = example.transform(test)
predicted = prediction.select("wages", "prediction", "TotalWages")
print("Displaying results from TrainValidationSplit with the Predicted dataset")
predicted.show()
# Out:
# Displaying results from TrainValidationSplit with the Predicted dataset
# +--------------------+------------------+----------+
# |               wages|        prediction|TotalWages|
# +--------------------+------------------+----------+
# |[31897.0,34289.0,...|  34572.5588365633|   34289.0|
# |[43955.0,46998.0,...| 48045.62950520257|   46998.0|
# |[47347.0,49172.0,...| 48045.62950520257|   49172.0|
# |[47347.0,50478.0,...|52462.623924493986|   50478.0|
# |[55969.0,61586.0,...|61653.309718778386|   61586.0|
# |[56294.0,61863.0,...|61653.309718778386|   61863.0|
# |[3317.0,12724.0,6...|12939.672514724653|   12724.0|
# |[38979.0,39626.0,...| 39336.42602898334|   39626.0|
# |[44389.0,44840.0,...| 43703.13219409577|   44840.0|
# |[45575.0,46305.0,...| 48051.07997088548|   46305.0|
# |[49471.0,50219.0,...|  52468.0743901769|   50219.0|
# |[55745.0,56705.0,...| 56893.88048049886|   56705.0|
# |[66723.0,67795.0,...| 67897.45906108731|   67795.0|
# |[1059.0,1059.0,0....| 915.6912916537415|    1059.0|
# |[3233.0,3270.0,0....| 3124.001087956406|    3270.0|
# |[4325.0,4325.0,0....| 4020.144882256075|    4325.0|
# |[5039.0,5131.0,0....| 5973.953562997987|    5131.0|
# |[5495.0,5495.0,0....| 5973.953562997987|    5495.0|
# |[9725.0,9918.0,0....| 10149.99978341936|    9918.0|
# |[9763.0,9909.0,0....| 10149.99978341936|    9909.0|
# +--------------------+------------------+----------+
# only showing top 20 rows
